# %% [markdown]
# # RECONOCIMIENTO DE VOZ
# Autores: Cora Salazar, Joshua Jian & Olortegui Perez, Kevin Estiben

# %% [markdown]
# ## Librerias

# %%
#!pip install speechrecognition

# %%
#!pip install pyaudio

# %%
import speech_recognition as sr

# %% [markdown]
# # Reconocer audio

# %% [markdown]
# ## En español

# %%
recognizer = sr.Recognizer()

with sr.Microphone() as source:
    print("Por favor, hable ahora...")
    audio = recognizer.listen(source)
    print("Gracias por su mensaje, procesando...")
    try:
        texto = recognizer.recognize_google(audio, language="es-ES")
        print("Usted dijo: " + texto)
    except sr.UnknownValueError:
        print("No se pudo entender el audio.")
    except sr.RequestError as e:
        print("Error al solicitar resultados; {0}".format(e))
# Out:
# Por favor, hable ahora...
# Gracias por su mensaje, procesando...
# Usted dijo: hi hello

# %% [markdown]
# ### En inglés

# %%
with sr.Microphone() as source:
    print("Por favor, hable ahora...")
    audio = recognizer.listen(source)
    print("Gracias por su mensaje, procesando...")
    try:
        texto = recognizer.recognize_google(audio, language="en-EN")
        print("Usted dijo: " + texto)
    except sr.UnknownValueError:
        print("No se pudo entender el audio.")
    except sr.RequestError as e:
        print("Error al solicitar resultados; {0}".format(e))
# Out:
# Por favor, hable ahora...
# Gracias por su mensaje, procesando...
# Usted dijo: hi this is a try

# %% [markdown]
# ### En quechua

# %%
"""
with sr.Microphone() as source:
    print("Por favor, hable en Quechua ahora...")
    audio = recognizer.listen(source)
    print("Gracias por su mensaje, procesando...")
    try:
        # Código de idioma para Quechua (Cusco)
        texto = recognizer.recognize_google(audio, language="qu-PE") 
        print("Usted dijo: " + texto)
    except sr.UnknownValueError:
        print("No se pudo entender el audio en Quechua.")
    except sr.RequestError as e:
        print("Error al solicitar resultados; {0}".format(e))
"""
# Out:
# '\nwith sr.Microphone() as source:\n    print("Por favor, hable en Quechua ahora...")\n    audio = recognizer.listen(source)\n    print("Gracias por su mensaje, procesando...")\n    try:\n        # Código de idioma para Quechua (Cusco)\n        texto = recognizer.recognize_google(audio, language="qu-PE") \n        print("Usted dijo: " + texto)\n    except sr.UnknownValueError:\n        print("No se pudo entender el audio en Quechua.")\n    except sr.RequestError as e:\n        print("Error al solicitar resultados; {0}".format(e))\n'
